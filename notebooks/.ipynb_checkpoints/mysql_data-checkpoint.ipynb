# %%
# !pip install sqlalchemy pymysql
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\user\anaconda3\lib\site-packages (2.0.43)
# Collecting pymysql
#   Downloading pymysql-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: greenlet>=1 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading pymysql-1.2.0-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.2.0

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv( "../data/processed/telco_customer_churn_clean.csv")

# %%
user = "root"
password = "sithu456"
host = "localhost"
port = "3306"
database = "telco_db"

engine = create_engine(
    f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}"
)

# %%
df.to_sql("raw_telco_churn", con=engine, if_exists="replace", index=False)
# Out:
# 7043
